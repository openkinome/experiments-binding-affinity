# %% [markdown]
# # Train a model with PyTorch
#
# > This notebook is a simplified version of our workflow. It exposes the basic details of the traning and evaluation loop more explicitly, but does not offer advanced features like early stopping, mini-batches or validation. Use the `*-lightning` version for those.

# %% [markdown]
# ## How to use
#
# Run `python run_notebook.py --help` for more information.

# %%
# If this is the template file (and not a copy) and you are introducing changes,
# update VERSION with the current date (YYYY.MM.DD)
VERSION = "2021.04.09"

# %% [markdown]
# ## ✏ Define hyper parameters

# %%
# TEMPLATE VALUES -- these are overriden (see below if executed) by papermill using a YAML or Python file as input

# DATA -- Glob paths must be relative to the root of the repository: REPO / features
NPZ_FILES = [
    "path/to/*.npz",
]

# Model -- specified with the full import path to the class object
MODEL_CLS = "kinoml.ml.torch_models.NeuralNetworkRegression"
MODEL_KWARGS = {"hidden_size": 350}  # input_shape is defined dynamically during training
WITH_OBSERVATION_MODEL = True

# Adam
LEARNING_RATE = 0.001
EPSILON = 1e-7
BETAS = 0.9, 0.999

# Trainer
MAX_EPOCHS = 50
N_SPLITS = 5
SHUFFLE_FOLDS = False
VALIDATION = False  # TODO: VALIDATION=True is not implemented yet!
MIN_ITEMS_PER_DATASET = 50  # skip datasets if len(data) < N

# Bootstrapping
N_BOOTSTRAPS = 1
BOOTSTRAP_SAMPLE_RATIO = 1

# Output
VERBOSE = False

## IGNORE THIS ONE
HERE = _dh[-1]

# %%
# Parameters
NPZ_FILES = [
    "example-ligand-only-chembl28-morgan512-1k-subsample/_output/ligand__SmilesToLigandFeaturizer__MorganFingerprintFeaturizer_nbits=512_radius=2/ChEMBLDatasetProvider/*.npz"
]
MODEL_CLS = "kinoml.ml.torch_models.NeuralNetworkRegression"
MODEL_KWARGS = {"hidden_shape": 350}
WITH_OBSERVATION_MODEL = True
LEARNING_RATE = 0.001
EPSILON = 1e-07
BETAS = [0.9, 0.999]
MAX_EPOCHS = 50
N_SPLITS = 5
SHUFFLE_FOLDS = False
VALIDATION = False
MIN_ITEMS_PER_DATASET = 10
N_BOOTSTRAPS = 1
BOOTSTRAP_SAMPLE_RATIO = 1
VERBOSE = False
HERE = "/home/jaime/devel/py/openkinome/experiments-binding-affinity/experiments/000_example-ligand-only-chembl28-subset"

# %% [markdown]
# ⚠ From here on, you should _not_ need to modify anything else 🤞
#
# ---
#
# Define key paths for data and outputs:

# %%
from pathlib import Path
from datetime import datetime

HERE = Path(HERE)

for parent in HERE.parents:
    if next(parent.glob(".github/"), None):
        REPO = parent
        break

FEATURES_STORE = REPO / "features"
        
OUT = HERE / "_output" / datetime.now().strftime("%Y%m%d-%H%M%S")
OUT.mkdir(parents=True, exist_ok=True)

print(f"This notebook:           HERE = ~/{HERE.relative_to(Path.home())}")
print(f"This repo:               REPO = ~/{REPO.relative_to(Path.home())}")
print(f"Features:      FEATURES_STORE = ~/{FEATURES_STORE.relative_to(Path.home())}")
print(f"Outputs in:               OUT = ~/{OUT.relative_to(Path.home())}")
# Out:
# This notebook:           HERE = ~/devel/py/openkinome/experiments-binding-affinity/experiments/000_example-ligand-only-chembl28-subset
# This repo:               REPO = ~/devel/py/openkinome/experiments-binding-affinity
# Features:      FEATURES_STORE = ~/devel/py/openkinome/experiments-binding-affinity/features
# Outputs in:               OUT = ~/devel/py/openkinome/experiments-binding-affinity/experiments/000_example-ligand-only-chembl28-subset/_output/20210409-163512

# %%
# Nasty trick: save all-caps local variables (CONSTANTS working as hyperparameters) so far in a dict to save it later
_hparams = {key: value for key, value in locals().items() if key.upper() == key and not key.startswith(("_", "OE_"))}

# %%
# TODO: Make all datasets use the same kinase identifiers
ONE_KINASE = {
    "ChEMBLDatasetProvider": "P35968",
    "PKIS2DatasetProvider": "ABL2",
}

# %%
from collections import defaultdict
from warnings import warn
import sys
import shutil

from IPython.display import Markdown
import numpy as np
import pandas as pd
import torch
from torch.utils.data import DataLoader, SubsetRandomSampler
import pytorch_lightning as pl

from kinoml.utils import seed_everything, import_object
from kinoml.core import measurements as measurement_types
from kinoml.datasets.torch_datasets import XyNpzTorchDataset
from kinoml.core.measurements import null_observation_model

# Fix the seed for reproducible random splits -- otherwise we get mixed train/test groups every time, biasing the model evaluation
seed_everything();
print("Run started at", datetime.now())
# Out:
# Warning: Unable to load toolkit 'OpenEye Toolkit'. The Open Force Field Toolkit does not require the OpenEye Toolkits, and can use RDKit/AmberTools instead. However, if you have a valid license for the OpenEye Toolkits, consider installing them for faster performance and additional file format support: https://docs.eyesopen.com/toolkits/python/quickstart-python/linuxosx.html OpenEye offers free Toolkit licenses for academics: https://www.eyesopen.com/academic-licensing
# Run started at 2021-04-09 16:35:13.808918

# %% [markdown]
# ## Load featurized data and create observation models
#
# We assume this path structure: `$REPO/features/_output/<FEATURIZATION>/<DATASET>/<GROUP>.npz`

# %%
DATASETS = []
MEASUREMENT_TYPES = set()
KINASES = set()
FEATURIZATIONS = set()
for glob in NPZ_FILES:
    npzs = list(FEATURES_STORE.glob(glob))
    if not npzs:
        warn(f"⚠ NPZ glob `{glob}` did not match any files!")
        continue
        
    for npz in npzs:
        kinase, measurement_type = npz.stem.split("__")
        dataset = npz.parent.name
        featurization = npz.parents[1].name
        
        MEASUREMENT_TYPES.add(measurement_type)
        KINASES.add(kinase)
        FEATURIZATIONS.add(featurization)
        
        ds = XyNpzTorchDataset(npz)
        ds.metadata = {
            "kinase": kinase,
            "measurement_type": measurement_type,
            "dataset": dataset,
            "featurization": featurization
        }
        DATASETS.append(ds)
        if not VALIDATION:
            ds.indices["test"] = np.concatenate([ds.indices["test"], ds.indices["val"]])
            ds.indices["val"] = np.array([])

if not DATASETS:
    raise ValueError("Provided `NPZ_FILES` did not result in any valid datasets!")

# %%
print("Observed...")
print(" - Measurement types:", len(MEASUREMENT_TYPES), "-->", *MEASUREMENT_TYPES)
print(" - Kinases:", len(KINASES), "-->", *KINASES)
# Out:
# Observed...
#  - Measurement types: 3 --> pKiMeasurement pKdMeasurement pIC50Measurement
#  - Kinases: 195 --> Q9H4B4 Q16644 P30530 P41743 Q96GD4 Q12866 Q15303 Q99558 Q08881 P07947 Q15759 O00311 O60674 Q56UN5 O43293 Q5S007 Q8TD19 O15111 Q16832 P53778 Q16513 Q96KB5 Q9HAZ1 Q9HC98 P22455 P49674 P51813 P53779 O43353 P19784 Q9NRP7 P54760 O14965 P45983 O96017 O60331 Q96RR4 P37173 P08581 P04629 P51955 Q9UPN9 P51617 O75385 P43405 P22607 Q12852 Q9UHD2 P78527 P41279 P09619 Q16539 P23443 P31751 Q08345 P21802 Q86YV6 P50750 Q15118 P06241 P06213 P29317 Q04759 P35968 P28482 O43318 Q5VT25 P16234 P48736 Q9NWZ3 P49840 P29376 Q58F21 Q02156 P07949 P49137 O00329 O60885 P51812 Q9Y616 P27361 Q8TBX8 Q04771 Q13315 O75716 Q00535 P53667 P06493 P30291 Q15835 P33981 Q14680 P53350 P52333 Q13627 Q15746 Q8N4C8 P31749 P42338 Q05513 Q14164 P08631 P27448 P17948 Q9UM73 Q05397 P68400 P00533 Q9UEE5 P25098 P29597 P11309 P42681 Q8NI60 O95835 P08069 P50613 P20794 P21675 O75460 P04049 P24941 P07333 Q9P1W9 P49760 Q8WTQ7 O14920 Q13464 O00418 P10721 Q9UIK4 P05129 Q15349 P17612 Q09013 Q6P3R8 O75116 Q9UQM7 P45984 P35916 P42685 Q9Y463 P49841 P00519 Q9NYY3 Q06187 Q13418 P42336 Q96PY6 Q15119 Q13535 Q9H2K8 Q13882 P53671 P78356 Q05823 P12931 Q06418 P11802 Q86V86 O15164 Q8IW41 P42345 P11362 P15056 P57059 O14757 Q9Y243 P36897 Q00534 Q9BUB5 Q13546 P06239 P25440 Q14289 Q02750 Q13153 P36888 P49759 P17252 P04626 Q8NE63 Q9NYL2 Q00537 Q05655 O96013 P35557 P07948 O75747 O15530 Q59H18 Q99683 P23458 Q9HBH9 P08922

# %% [markdown]
# ## Check X duplication
#
# There's a chance we have several measurements per ligand, or, depending on the featurization scheme, even hash collisions... Let's quantify the amount of input tensor duplication we are facing.

# %%
for mtype in MEASUREMENT_TYPES:
    display(Markdown(f"#### {mtype}"))
    unique = {}
    for ds in DATASETS:
        if ds.metadata["measurement_type"] == mtype:
            all_ = ds.data_X.shape[0]
            unique_ = np.unique(ds.data_X, axis=0).shape[0]
            unique[ds.metadata["kinase"]] = {"all": all_, "unique": unique_}
    df = pd.DataFrame.from_dict(unique).T
    df["uniqueness"] = df["unique"] / df["all"]
    # This is how you highlight rows in pandas!
    df = df.describe().style.apply(lambda x: ['font-weight: bold' for v in x], subset=pd.IndexSlice[["mean", "std"], :])
    display(df)
# Out:
# #### pKiMeasurement
# <style  type="text/css" >
# #T_f0d47_row1_col0,#T_f0d47_row1_col1,#T_f0d47_row1_col2,#T_f0d47_row2_col0,#T_f0d47_row2_col1,#T_f0d47_row2_col2{
#             font-weight:  bold;
#         }</style><table id="T_f0d47_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >all</th>        <th class="col_heading level0 col1" >unique</th>        <th class="col_heading level0 col2" >uniqueness</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f0d47_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_f0d47_row0_col0" class="data row0 col0" >37.000000</td>
#                         <td id="T_f0d47_row0_col1" class="data row0 col1" >37.000000</td>
#                         <td id="T_f0d47_row0_col2" class="data row0 col2" >37.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_f0d47_level0_row1" class="row_heading level0 row1" >mean</th>
#                         <td id="T_f0d47_row1_col0" class="data row1 col0" >2.270270</td>
#                         <td id="T_f0d47_row1_col1" class="data row1 col1" >2.270270</td>
#                         <td id="T_f0d47_row1_col2" class="data row1 col2" >1.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_f0d47_level0_row2" class="row_heading level0 row2" >std</th>
#                         <td id="T_f0d47_row2_col0" class="data row2 col0" >2.063555</td>
#                         <td id="T_f0d47_row2_col1" class="data row2 col1" >2.063555</td>
#                         <td id="T_f0d47_row2_col2" class="data row2 col2" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_f0d47_level0_row3" class="row_heading level0 row3" >min</th>
#                         <td id="T_f0d47_row3_col0" class="data row3 col0" >1.000000</td>
#                         <td id="T_f0d47_row3_col1" class="data row3 col1" >1.000000</td>
#                         <td id="T_f0d47_row3_col2" class="data row3 col2" >1.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_f0d47_level0_row4" class="row_heading level0 row4" >25%</th>
#                         <td id="T_f0d47_row4_col0" class="data row4 col0" >1.000000</td>
#                         <td id="T_f0d47_row4_col1" class="data row4 col1" >1.000000</td>
#                         <td id="T_f0d47_row4_col2" class="data row4 col2" >1.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_f0d47_level0_row5" class="row_heading level0 row5" >50%</th>
#                         <td id="T_f0d47_row5_col0" class="data row5 col0" >1.000000</td>
#                         <td id="T_f0d47_row5_col1" class="data row5 col1" >1.000000</td>
#                         <td id="T_f0d47_row5_col2" class="data row5 col2" >1.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_f0d47_level0_row6" class="row_heading level0 row6" >75%</th>
#                         <td id="T_f0d47_row6_col0" class="data row6 col0" >2.000000</td>
#                         <td id="T_f0d47_row6_col1" class="data row6 col1" >2.000000</td>
#                         <td id="T_f0d47_row6_col2" class="data row6 col2" >1.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_f0d47_level0_row7" class="row_heading level0 row7" >max</th>
#                         <td id="T_f0d47_row7_col0" class="data row7 col0" >10.000000</td>
#                         <td id="T_f0d47_row7_col1" class="data row7 col1" >10.000000</td>
#                         <td id="T_f0d47_row7_col2" class="data row7 col2" >1.000000</td>
#             </tr>
#     </tbody></table>
# #### pKdMeasurement
# <style  type="text/css" >
# #T_1b6a6_row1_col0,#T_1b6a6_row1_col1,#T_1b6a6_row1_col2,#T_1b6a6_row2_col0,#T_1b6a6_row2_col1,#T_1b6a6_row2_col2{
#             font-weight:  bold;
#         }</style><table id="T_1b6a6_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >all</th>        <th class="col_heading level0 col1" >unique</th>        <th class="col_heading level0 col2" >uniqueness</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1b6a6_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_1b6a6_row0_col0" class="data row0 col0" >58.000000</td>
#                         <td id="T_1b6a6_row0_col1" class="data row0 col1" >58.000000</td>
#                         <td id="T_1b6a6_row0_col2" class="data row0 col2" >58.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_1b6a6_level0_row1" class="row_heading level0 row1" >mean</th>
#                         <td id="T_1b6a6_row1_col0" class="data row1 col0" >1.155172</td>
#                         <td id="T_1b6a6_row1_col1" class="data row1 col1" >1.155172</td>
#                         <td id="T_1b6a6_row1_col2" class="data row1 col2" >1.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_1b6a6_level0_row2" class="row_heading level0 row2" >std</th>
#                         <td id="T_1b6a6_row2_col0" class="data row2 col0" >0.410465</td>
#                         <td id="T_1b6a6_row2_col1" class="data row2 col1" >0.410465</td>
#                         <td id="T_1b6a6_row2_col2" class="data row2 col2" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_1b6a6_level0_row3" class="row_heading level0 row3" >min</th>
#                         <td id="T_1b6a6_row3_col0" class="data row3 col0" >1.000000</td>
#                         <td id="T_1b6a6_row3_col1" class="data row3 col1" >1.000000</td>
#                         <td id="T_1b6a6_row3_col2" class="data row3 col2" >1.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_1b6a6_level0_row4" class="row_heading level0 row4" >25%</th>
#                         <td id="T_1b6a6_row4_col0" class="data row4 col0" >1.000000</td>
#                         <td id="T_1b6a6_row4_col1" class="data row4 col1" >1.000000</td>
#                         <td id="T_1b6a6_row4_col2" class="data row4 col2" >1.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_1b6a6_level0_row5" class="row_heading level0 row5" >50%</th>
#                         <td id="T_1b6a6_row5_col0" class="data row5 col0" >1.000000</td>
#                         <td id="T_1b6a6_row5_col1" class="data row5 col1" >1.000000</td>
#                         <td id="T_1b6a6_row5_col2" class="data row5 col2" >1.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_1b6a6_level0_row6" class="row_heading level0 row6" >75%</th>
#                         <td id="T_1b6a6_row6_col0" class="data row6 col0" >1.000000</td>
#                         <td id="T_1b6a6_row6_col1" class="data row6 col1" >1.000000</td>
#                         <td id="T_1b6a6_row6_col2" class="data row6 col2" >1.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_1b6a6_level0_row7" class="row_heading level0 row7" >max</th>
#                         <td id="T_1b6a6_row7_col0" class="data row7 col0" >3.000000</td>
#                         <td id="T_1b6a6_row7_col1" class="data row7 col1" >3.000000</td>
#                         <td id="T_1b6a6_row7_col2" class="data row7 col2" >1.000000</td>
#             </tr>
#     </tbody></table>
# #### pIC50Measurement
# <style  type="text/css" >
# #T_1e6e7_row1_col0,#T_1e6e7_row1_col1,#T_1e6e7_row1_col2,#T_1e6e7_row2_col0,#T_1e6e7_row2_col1,#T_1e6e7_row2_col2{
#             font-weight:  bold;
#         }</style><table id="T_1e6e7_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >all</th>        <th class="col_heading level0 col1" >unique</th>        <th class="col_heading level0 col2" >uniqueness</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1e6e7_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_1e6e7_row0_col0" class="data row0 col0" >159.000000</td>
#                         <td id="T_1e6e7_row0_col1" class="data row0 col1" >159.000000</td>
#                         <td id="T_1e6e7_row0_col2" class="data row0 col2" >159.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_1e6e7_level0_row1" class="row_heading level0 row1" >mean</th>
#                         <td id="T_1e6e7_row1_col0" class="data row1 col0" >5.339623</td>
#                         <td id="T_1e6e7_row1_col1" class="data row1 col1" >5.339623</td>
#                         <td id="T_1e6e7_row1_col2" class="data row1 col2" >1.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_1e6e7_level0_row2" class="row_heading level0 row2" >std</th>
#                         <td id="T_1e6e7_row2_col0" class="data row2 col0" >7.259067</td>
#                         <td id="T_1e6e7_row2_col1" class="data row2 col1" >7.259067</td>
#                         <td id="T_1e6e7_row2_col2" class="data row2 col2" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_1e6e7_level0_row3" class="row_heading level0 row3" >min</th>
#                         <td id="T_1e6e7_row3_col0" class="data row3 col0" >1.000000</td>
#                         <td id="T_1e6e7_row3_col1" class="data row3 col1" >1.000000</td>
#                         <td id="T_1e6e7_row3_col2" class="data row3 col2" >1.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_1e6e7_level0_row4" class="row_heading level0 row4" >25%</th>
#                         <td id="T_1e6e7_row4_col0" class="data row4 col0" >1.000000</td>
#                         <td id="T_1e6e7_row4_col1" class="data row4 col1" >1.000000</td>
#                         <td id="T_1e6e7_row4_col2" class="data row4 col2" >1.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_1e6e7_level0_row5" class="row_heading level0 row5" >50%</th>
#                         <td id="T_1e6e7_row5_col0" class="data row5 col0" >3.000000</td>
#                         <td id="T_1e6e7_row5_col1" class="data row5 col1" >3.000000</td>
#                         <td id="T_1e6e7_row5_col2" class="data row5 col2" >1.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_1e6e7_level0_row6" class="row_heading level0 row6" >75%</th>
#                         <td id="T_1e6e7_row6_col0" class="data row6 col0" >6.000000</td>
#                         <td id="T_1e6e7_row6_col1" class="data row6 col1" >6.000000</td>
#                         <td id="T_1e6e7_row6_col2" class="data row6 col2" >1.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_1e6e7_level0_row7" class="row_heading level0 row7" >max</th>
#                         <td id="T_1e6e7_row7_col0" class="data row7 col0" >51.000000</td>
#                         <td id="T_1e6e7_row7_col1" class="data row7 col1" >51.000000</td>
#                         <td id="T_1e6e7_row7_col2" class="data row7 col2" >1.000000</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Now that we have all the data-dependent objects, we can start with the model-specific definitions.

# %% [markdown]
# ### Training loop

# %%
from kinoml.ml.lightning_modules import KFold3Way, KFold
from IPython.display import Markdown
from tqdm.auto import trange, tqdm
from kinoml.ml.torch_models import NeuralNetworkRegression
from ipywidgets import HBox, VBox, Output, HTML
from kinoml.analysis.plots import predicted_vs_observed, performance
from kinoml.utils import fill_until_next_multiple
import pandas as pd
import torch.nn as nn

if VALIDATION:
    kfold = KFold3Way(n_splits=N_SPLITS, shuffle=SHUFFLE_FOLDS)
    ttypes = ["train", "val", "test"]
else:
    kfold = KFold(n_splits=N_SPLITS, shuffle=SHUFFLE_FOLDS)
    ttypes = ["train", "test"]

ModelCls = import_object(MODEL_CLS)
    
kinase_metrics = defaultdict(dict)
for dataset in tqdm(DATASETS):
    kinase = dataset.metadata["kinase"]
    mtype = dataset.metadata["measurement_type"]
    if dataset.data_X.shape[0] < MIN_ITEMS_PER_DATASET:
        warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
        continue
            
    if VERBOSE:
        display(Markdown(f"#### {mtype}"))

    mtype_class = getattr(measurement_types, mtype)
    obs_model = mtype_class.observation_model(backend="pytorch")
    metrics = defaultdict(list)

    for fold_index, splits in enumerate(kfold.split(dataset.data_X, dataset.data_y)):
        if VALIDATION:
            train_indices, val_indices, test_indices = splits
        else:
            train_indices, test_indices = splits

        if VERBOSE:
            display(Markdown(f"##### Fold {fold_index}"))

        ####
        # TRAIN
        ####
        x_train = dataset.data_X[train_indices].float()
        x_test = dataset.data_X[test_indices].float()
        y_train = dataset.data_y[train_indices]
        y_test = dataset.data_y[test_indices]

        if VALIDATION:
            x_val = dataset.data_X[val_indices].float()
            y_val = dataset.data_y[val_indices]
        
        input_shape = ModelCls.estimate_input_shape(x_train)
        nn_model = ModelCls(input_shape=input_shape, **MODEL_KWARGS)
        nn_model.train(True)

        optimizer = torch.optim.Adam(nn_model.parameters(), lr=LEARNING_RATE, eps=EPSILON, betas=BETAS)
        loss_function = torch.nn.MSELoss()

        if VERBOSE:
            range_epochs = trange(MAX_EPOCHS, desc="Epochs (+ featurization...)")
        else:
            range_epochs = range(MAX_EPOCHS)
        for epoch in range_epochs:
            optimizer.zero_grad()

            prediction = nn_model(x_train)
            if WITH_OBSERVATION_MODEL:
                prediction = obs_model(prediction)

            prediction = prediction.view_as(y_train)

            loss = loss_function(prediction, y_train)
            if VERBOSE:
                range_epochs.set_description(f"Epochs (loss={loss.item():.2e})")

            if VALIDATION:
                warn("Validation step not implemented yet")


            # Gradients w.r.t. parameters
            loss.backward()

            # Optimizer
            optimizer.step()
        
        ###
        # Save model's state -- you will still need to instantiate the model class!
        # Possibly using something like:
        # model = import_object(MODEL_CLS)(**MODEL_KWARGS)
        # model.load_state_dict(torch.load("state_dict.pt"))
        ###
        torch.save(nn_model.state_dict(), OUT / f"state_dict_{kinase}_{mtype}_fold{fold_index}.pt")
        
        ####
        # EVAL
        ####
        nn_model.eval()
        outputs = []
        for ttype in ttypes:
            output = Output()
            with output:
                title = f"fold={fold_index}, {ttype}={locals()[f'{ttype}_indices'].shape[0]}"
                print(title)
                print("-"*(len(title)))

                observed = locals()[f"y_{ttype}"]

                with torch.no_grad():
                    predicted = nn_model(locals()[f"x_{ttype}"])
                    if WITH_OBSERVATION_MODEL:
                        predicted = obs_model(predicted)

                predicted = predicted.view_as(observed).detach().numpy()
                observed = observed.detach().numpy()
                these_metrics = performance(predicted, observed, n_boot=N_BOOTSTRAPS, sample_ratio=BOOTSTRAP_SAMPLE_RATIO)
                metrics[ttype].append(these_metrics)
                if VERBOSE:
                    display(predicted_vs_observed(predicted, observed, mtype_class, with_metrics=False))

            outputs.append(output)
        if VERBOSE:
            display(HBox(outputs))

    # Average performances

    average = defaultdict(dict)
    for key in metrics["test"][0]:
        for label in ttypes:
            # this zero here ---v is super important! we only want the mean of the means!
            values =  [fold[key][0] for fold in metrics[label]]
            average[label][key] = {
                "mean": np.mean(values),
                "std": np.std(values)
            }
    if VERBOSE:
        for label in ttypes:    
            display(HTML(f"Bootstrapped average across folds ({label}):"))
            display(pd.DataFrame.from_dict(average[label]))
    kinase_metrics[kinase][mtype] = average
# Out:
#   0%|          | 0/254 [00:00<?, ?it/s]
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q9Y463 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q06187 because it has less than 10 entries for type pKiMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P24941 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P17252 because it has less than 10 entries for type pKiMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q9H2K8 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring O14965 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q16832 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P41743 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P42336 because it has less than 10 entries for type pKiMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q13418 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q96PY6 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P04049 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q00535 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q15119 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q8TD19 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P49674 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q13627 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring O00418 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring O60885 because it has less than 10 entries for type pKiMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P68400 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q05513 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P51617 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q56UN5 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P36888 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q14164 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P07333 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q02156 because it has less than 10 entries for type pKiMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P49841 because it has less than 10 entries for type pKiMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P52333 because it has less than 10 entries for type pKiMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P53350 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q96KB5 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q9P1W9 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P00533 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P42345 because it has less than 10 entries for type pKiMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P42685 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q86V86 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P50613 because it has less than 10 entries for type pKiMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q04771 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring O00311 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P07947 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P05129 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q16644 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring O75460 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring O14757 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q99558 because it has less than 10 entries for type pKiMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q9UHD2 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P49760 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P10721 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P22607 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q00537 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q99683 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q08345 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring O15111 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring O15530 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring O96013 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q14289 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q16539 because it has less than 10 entries for type pKiMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring O60885 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q16832 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q15835 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P35557 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P25440 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P00519 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P17948 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P11802 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P12931 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P31751 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P42681 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P48736 because it has less than 10 entries for type pKiMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P19784 because it has less than 10 entries for type pKiMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P07333 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P23458 because it has less than 10 entries for type pKiMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P16234 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring O96017 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P27361 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P17612 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring O43353 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q09013 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P22607 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring O60674 because it has less than 10 entries for type pKiMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q5S007 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring O15164 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P17252 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q15746 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P51955 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q9HAZ1 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P12931 because it has less than 10 entries for type pKiMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q05397 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P24941 because it has less than 10 entries for type pKiMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q9P1W9 because it has less than 10 entries for type pKiMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q58F21 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q13153 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q12852 because it has less than 10 entries for type pKiMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q9HC98 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P37173 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q13535 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P23443 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring O43353 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P10721 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P49759 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring O75716 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P07948 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q00535 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q05397 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q13627 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q04759 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P36888 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P53779 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q08345 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q5S007 because it has less than 10 entries for type pKiMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q15303 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P31749 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q8NI60 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P35916 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q9UQM7 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P42681 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P07949 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q05655 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q9UPN9 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q8WTQ7 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P17948 because it has less than 10 entries for type pKiMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q12866 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q15118 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P50613 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P53671 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q14680 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P27448 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q6P3R8 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q16539 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P33981 because it has less than 10 entries for type pKiMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P21675 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P30530 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P25098 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P51812 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P31751 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q86YV6 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q9NYY3 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P08581 because it has less than 10 entries for type pKiMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P78527 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P29597 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P33981 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q9NRP7 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P09619 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q9NWZ3 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q14289 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q02156 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P78356 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q16513 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring O75747 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring O75116 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P21802 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P08631 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q9Y243 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q15759 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P06239 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q00534 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q13315 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q9BUB5 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P53667 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P08922 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P49760 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P50750 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q9Y616 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q9UIK4 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q8IW41 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P07333 because it has less than 10 entries for type pKiMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P06493 because it has less than 10 entries for type pKiMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q59H18 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q8NE63 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q8N4C8 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P29317 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q05823 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q96GD4 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P57059 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring O60331 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring O43318 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P45984 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring O14920 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P41279 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q9HBH9 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P68400 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P33981 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q8TD19 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring O95835 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q9H4B4 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q13882 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q02750 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P15056 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q06418 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q13464 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P49840 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P00519 because it has less than 10 entries for type pKiMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q96RR4 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P49137 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P51813 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q05655 because it has less than 10 entries for type pKiMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P30291 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q5VT25 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P36897 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring O00329 because it has less than 10 entries for type pKiMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q9UEE5 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q9UM73 because it has less than 10 entries for type pKiMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P35968 because it has less than 10 entries for type pKiMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P00533 because it has less than 10 entries for type pKiMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P53779 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P06239 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P20794 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q86V86 because it has less than 10 entries for type pKiMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q15349 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P04626 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring O96013 because it has less than 10 entries for type pKiMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q9NYL2 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring O43293 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P22455 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P29597 because it has less than 10 entries for type pKiMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q13546 because it has less than 10 entries for type pKiMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q8TBX8 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P06241 because it has less than 10 entries for type pKiMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P54760 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q9UM73 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P29376 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring O75385 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q9H4B4 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P06241 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring O14965 because it has less than 10 entries for type pKdMeasurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring Q08881 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P45983 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P53778 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")
# <ipython-input-11-f03f80140d97>:25: UserWarning: Ignoring P06213 because it has less than 10 entries for type pIC50Measurement
#   warn(f"Ignoring {kinase} because it has less than {MIN_ITEMS_PER_DATASET} entries for type {mtype}")

# %% [markdown]
# ### Summary
#
# `kinase_metrics` is a nested dictionary with these dimensions:
#
# - kinase name
# - measurement type
# - metric
# - mean & standard deviation

# %%
import json

display(Markdown(f"""
### Configuration 

```json
{json.dumps(_hparams, default=str, indent=2)}
```
"""))

if VERBOSE:
    display(Markdown(f"""

    ### Kinase metrics

    ```json
    {json.dumps(kinase_metrics, default=str, indent=2)}
    ```
    """))
# Out:
# ### Configuration
#
# ```json
# {
#   "VERSION": "2021.04.09",
#   "NPZ_FILES": [
#     "example-ligand-only-chembl28-morgan512-1k-subsample/_output/ligand__SmilesToLigandFeaturizer__MorganFingerprintFeaturizer_nbits=512_radius=2/ChEMBLDatasetProvider/*.npz"
#   ],
#   "MODEL_CLS": "kinoml.ml.torch_models.NeuralNetworkRegression",
#   "MODEL_KWARGS": {
#     "hidden_shape": 350
#   },
#   "WITH_OBSERVATION_MODEL": true,
#   "LEARNING_RATE": 0.001,
#   "EPSILON": 1e-07,
#   "BETAS": [
#     0.9,
#     0.999
#   ],
#   "MAX_EPOCHS": 50,
#   "N_SPLITS": 5,
#   "SHUFFLE_FOLDS": false,
#   "VALIDATION": false,
#   "MIN_ITEMS_PER_DATASET": 10,
#   "N_BOOTSTRAPS": 1,
#   "BOOTSTRAP_SAMPLE_RATIO": 1,
#   "VERBOSE": false,
#   "HERE": "/home/jaime/devel/py/openkinome/experiments-binding-affinity/experiments/000_example-ligand-only-chembl28-subset",
#   "REPO": "/home/jaime/devel/py/openkinome/experiments-binding-affinity",
#   "FEATURES_STORE": "/home/jaime/devel/py/openkinome/experiments-binding-affinity/features",
#   "OUT": "/home/jaime/devel/py/openkinome/experiments-binding-affinity/experiments/000_example-ligand-only-chembl28-subset/_output/20210409-163512"
# }
# ```

# %%
for mtype in MEASUREMENT_TYPES:
    display(Markdown(f"#### {mtype}"))

    dict_of_flattened_metrics = {}
    for kinase_name, measurement_type_dict in sorted(kinase_metrics.items(), key=lambda kv: kv[0].lower()):
        flattened_metrics = {}
        for train_test_key, train_test_dict in measurement_type_dict.get(mtype, {}).items():
            for metric_key, mean_std_dict in train_test_dict.items():
                for mean_std_key, value in mean_std_dict.items():
                    flattened_metrics[f"{train_test_key}_{metric_key}_{mean_std_key}"] = (value,)
        if flattened_metrics:
            dict_of_flattened_metrics[kinase_name] = pd.DataFrame.from_dict(flattened_metrics)
    
    if not dict_of_flattened_metrics:
        continue
    
    df = pd.concat(dict_of_flattened_metrics)
    df.index = [index[0] for index in df.index]
    with pd.option_context("display.float_format", "{:.3f}".format, "display.max_rows", len(df)):
        display(df.style.background_gradient(subset=["train_r2_mean", "test_r2_mean"], low=0, high=1, vmin=0, vmax=1))
        display(df.describe()[["train_r2_mean", "train_r2_std", "test_r2_mean", "test_r2_std"]].describe().style.apply(lambda x: ['font-weight: bold' for v in x], subset=pd.IndexSlice[["mean", "std"], :]))
# Out:
# #### pKiMeasurement
# <style  type="text/css" >
# #T_82922_row0_col4{
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }#T_82922_row0_col12{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_82922_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >train_mae_mean</th>        <th class="col_heading level0 col1" >train_mae_std</th>        <th class="col_heading level0 col2" >train_mse_mean</th>        <th class="col_heading level0 col3" >train_mse_std</th>        <th class="col_heading level0 col4" >train_r2_mean</th>        <th class="col_heading level0 col5" >train_r2_std</th>        <th class="col_heading level0 col6" >train_rmse_mean</th>        <th class="col_heading level0 col7" >train_rmse_std</th>        <th class="col_heading level0 col8" >test_mae_mean</th>        <th class="col_heading level0 col9" >test_mae_std</th>        <th class="col_heading level0 col10" >test_mse_mean</th>        <th class="col_heading level0 col11" >test_mse_std</th>        <th class="col_heading level0 col12" >test_r2_mean</th>        <th class="col_heading level0 col13" >test_r2_std</th>        <th class="col_heading level0 col14" >test_rmse_mean</th>        <th class="col_heading level0 col15" >test_rmse_std</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_82922_level0_row0" class="row_heading level0 row0" >P11309</th>
#                         <td id="T_82922_row0_col0" class="data row0 col0" >1.085747</td>
#                         <td id="T_82922_row0_col1" class="data row0 col1" >0.101512</td>
#                         <td id="T_82922_row0_col2" class="data row0 col2" >1.398925</td>
#                         <td id="T_82922_row0_col3" class="data row0 col3" >0.200672</td>
#                         <td id="T_82922_row0_col4" class="data row0 col4" >0.431285</td>
#                         <td id="T_82922_row0_col5" class="data row0 col5" >0.197629</td>
#                         <td id="T_82922_row0_col6" class="data row0 col6" >1.179673</td>
#                         <td id="T_82922_row0_col7" class="data row0 col7" >0.085417</td>
#                         <td id="T_82922_row0_col8" class="data row0 col8" >0.828195</td>
#                         <td id="T_82922_row0_col9" class="data row0 col9" >0.610180</td>
#                         <td id="T_82922_row0_col10" class="data row0 col10" >1.058226</td>
#                         <td id="T_82922_row0_col11" class="data row0 col11" >1.182908</td>
#                         <td id="T_82922_row0_col12" class="data row0 col12" >0.000000</td>
#                         <td id="T_82922_row0_col13" class="data row0 col13" >0.000000</td>
#                         <td id="T_82922_row0_col14" class="data row0 col14" >0.828195</td>
#                         <td id="T_82922_row0_col15" class="data row0 col15" >0.610180</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
# #T_f6554_row1_col0,#T_f6554_row1_col1,#T_f6554_row1_col2,#T_f6554_row1_col3,#T_f6554_row2_col0,#T_f6554_row2_col1,#T_f6554_row2_col2,#T_f6554_row2_col3{
#             font-weight:  bold;
#         }</style><table id="T_f6554_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >train_r2_mean</th>        <th class="col_heading level0 col1" >train_r2_std</th>        <th class="col_heading level0 col2" >test_r2_mean</th>        <th class="col_heading level0 col3" >test_r2_std</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f6554_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_f6554_row0_col0" class="data row0 col0" >7.000000</td>
#                         <td id="T_f6554_row0_col1" class="data row0 col1" >7.000000</td>
#                         <td id="T_f6554_row0_col2" class="data row0 col2" >7.000000</td>
#                         <td id="T_f6554_row0_col3" class="data row0 col3" >7.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_f6554_level0_row1" class="row_heading level0 row1" >mean</th>
#                         <td id="T_f6554_row1_col0" class="data row1 col0" >0.512530</td>
#                         <td id="T_f6554_row1_col1" class="data row1 col1" >0.312253</td>
#                         <td id="T_f6554_row1_col2" class="data row1 col2" >0.142857</td>
#                         <td id="T_f6554_row1_col3" class="data row1 col3" >0.142857</td>
#             </tr>
#             <tr>
#                         <th id="T_f6554_level0_row2" class="row_heading level0 row2" >std</th>
#                         <td id="T_f6554_row2_col0" class="data row2 col0" >0.214954</td>
#                         <td id="T_f6554_row2_col1" class="data row2 col1" >0.303268</td>
#                         <td id="T_f6554_row2_col2" class="data row2 col2" >0.377964</td>
#                         <td id="T_f6554_row2_col3" class="data row2 col3" >0.377964</td>
#             </tr>
#             <tr>
#                         <th id="T_f6554_level0_row3" class="row_heading level0 row3" >min</th>
#                         <td id="T_f6554_row3_col0" class="data row3 col0" >0.431285</td>
#                         <td id="T_f6554_row3_col1" class="data row3 col1" >0.197629</td>
#                         <td id="T_f6554_row3_col2" class="data row3 col2" >0.000000</td>
#                         <td id="T_f6554_row3_col3" class="data row3 col3" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_f6554_level0_row4" class="row_heading level0 row4" >25%</th>
#                         <td id="T_f6554_row4_col0" class="data row4 col0" >0.431285</td>
#                         <td id="T_f6554_row4_col1" class="data row4 col1" >0.197629</td>
#                         <td id="T_f6554_row4_col2" class="data row4 col2" >0.000000</td>
#                         <td id="T_f6554_row4_col3" class="data row4 col3" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_f6554_level0_row5" class="row_heading level0 row5" >50%</th>
#                         <td id="T_f6554_row5_col0" class="data row5 col0" >0.431285</td>
#                         <td id="T_f6554_row5_col1" class="data row5 col1" >0.197629</td>
#                         <td id="T_f6554_row5_col2" class="data row5 col2" >0.000000</td>
#                         <td id="T_f6554_row5_col3" class="data row5 col3" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_f6554_level0_row6" class="row_heading level0 row6" >75%</th>
#                         <td id="T_f6554_row6_col0" class="data row6 col0" >0.431285</td>
#                         <td id="T_f6554_row6_col1" class="data row6 col1" >0.197629</td>
#                         <td id="T_f6554_row6_col2" class="data row6 col2" >0.000000</td>
#                         <td id="T_f6554_row6_col3" class="data row6 col3" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_f6554_level0_row7" class="row_heading level0 row7" >max</th>
#                         <td id="T_f6554_row7_col0" class="data row7 col0" >1.000000</td>
#                         <td id="T_f6554_row7_col1" class="data row7 col1" >1.000000</td>
#                         <td id="T_f6554_row7_col2" class="data row7 col2" >1.000000</td>
#                         <td id="T_f6554_row7_col3" class="data row7 col3" >1.000000</td>
#             </tr>
#     </tbody></table>
# #### pKdMeasurement
# #### pIC50Measurement
# <style  type="text/css" >
# #T_9059f_row0_col4{
#             background-color:  #afc1dd;
#             color:  #000000;
#         }#T_9059f_row0_col12,#T_9059f_row1_col12,#T_9059f_row2_col12,#T_9059f_row3_col12,#T_9059f_row4_col12,#T_9059f_row5_col12,#T_9059f_row6_col12,#T_9059f_row7_col12,#T_9059f_row8_col12,#T_9059f_row9_col12,#T_9059f_row10_col12,#T_9059f_row11_col12,#T_9059f_row12_col12,#T_9059f_row13_col12,#T_9059f_row14_col4,#T_9059f_row14_col12,#T_9059f_row15_col12,#T_9059f_row16_col12,#T_9059f_row17_col12,#T_9059f_row18_col12,#T_9059f_row19_col12,#T_9059f_row20_col12,#T_9059f_row21_col12,#T_9059f_row22_col12,#T_9059f_row23_col12{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_9059f_row1_col4{
#             background-color:  #e3e0ee;
#             color:  #000000;
#         }#T_9059f_row2_col4{
#             background-color:  #abbfdc;
#             color:  #000000;
#         }#T_9059f_row3_col4{
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }#T_9059f_row4_col4{
#             background-color:  #acc0dd;
#             color:  #000000;
#         }#T_9059f_row5_col4{
#             background-color:  #84b0d3;
#             color:  #000000;
#         }#T_9059f_row6_col4{
#             background-color:  #e0dded;
#             color:  #000000;
#         }#T_9059f_row7_col4{
#             background-color:  #a1bbda;
#             color:  #000000;
#         }#T_9059f_row8_col4{
#             background-color:  #96b6d7;
#             color:  #000000;
#         }#T_9059f_row9_col4{
#             background-color:  #8cb3d5;
#             color:  #000000;
#         }#T_9059f_row10_col4{
#             background-color:  #97b7d7;
#             color:  #000000;
#         }#T_9059f_row11_col4{
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }#T_9059f_row12_col4{
#             background-color:  #b0c2de;
#             color:  #000000;
#         }#T_9059f_row13_col4{
#             background-color:  #cacee5;
#             color:  #000000;
#         }#T_9059f_row15_col4{
#             background-color:  #adc1dd;
#             color:  #000000;
#         }#T_9059f_row16_col4{
#             background-color:  #83afd3;
#             color:  #000000;
#         }#T_9059f_row17_col4{
#             background-color:  #b5c4df;
#             color:  #000000;
#         }#T_9059f_row18_col4{
#             background-color:  #a7bddb;
#             color:  #000000;
#         }#T_9059f_row19_col4{
#             background-color:  #e4e1ef;
#             color:  #000000;
#         }#T_9059f_row20_col4{
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }#T_9059f_row21_col4{
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }#T_9059f_row22_col4{
#             background-color:  #c8cde4;
#             color:  #000000;
#         }#T_9059f_row23_col4{
#             background-color:  #dfddec;
#             color:  #000000;
#         }</style><table id="T_9059f_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >train_mae_mean</th>        <th class="col_heading level0 col1" >train_mae_std</th>        <th class="col_heading level0 col2" >train_mse_mean</th>        <th class="col_heading level0 col3" >train_mse_std</th>        <th class="col_heading level0 col4" >train_r2_mean</th>        <th class="col_heading level0 col5" >train_r2_std</th>        <th class="col_heading level0 col6" >train_rmse_mean</th>        <th class="col_heading level0 col7" >train_rmse_std</th>        <th class="col_heading level0 col8" >test_mae_mean</th>        <th class="col_heading level0 col9" >test_mae_std</th>        <th class="col_heading level0 col10" >test_mse_mean</th>        <th class="col_heading level0 col11" >test_mse_std</th>        <th class="col_heading level0 col12" >test_r2_mean</th>        <th class="col_heading level0 col13" >test_r2_std</th>        <th class="col_heading level0 col14" >test_rmse_mean</th>        <th class="col_heading level0 col15" >test_rmse_std</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9059f_level0_row0" class="row_heading level0 row0" >O00329</th>
#                         <td id="T_9059f_row0_col0" class="data row0 col0" >0.525646</td>
#                         <td id="T_9059f_row0_col1" class="data row0 col1" >0.043479</td>
#                         <td id="T_9059f_row0_col2" class="data row0 col2" >0.393190</td>
#                         <td id="T_9059f_row0_col3" class="data row0 col3" >0.071145</td>
#                         <td id="T_9059f_row0_col4" class="data row0 col4" >0.699709</td>
#                         <td id="T_9059f_row0_col5" class="data row0 col5" >0.082722</td>
#                         <td id="T_9059f_row0_col6" class="data row0 col6" >0.624597</td>
#                         <td id="T_9059f_row0_col7" class="data row0 col7" >0.055393</td>
#                         <td id="T_9059f_row0_col8" class="data row0 col8" >1.458050</td>
#                         <td id="T_9059f_row0_col9" class="data row0 col9" >0.531108</td>
#                         <td id="T_9059f_row0_col10" class="data row0 col10" >2.677714</td>
#                         <td id="T_9059f_row0_col11" class="data row0 col11" >1.710035</td>
#                         <td id="T_9059f_row0_col12" class="data row0 col12" >-4.760219</td>
#                         <td id="T_9059f_row0_col13" class="data row0 col13" >5.477612</td>
#                         <td id="T_9059f_row0_col14" class="data row0 col14" >1.539789</td>
#                         <td id="T_9059f_row0_col15" class="data row0 col15" >0.553862</td>
#             </tr>
#             <tr>
#                         <th id="T_9059f_level0_row1" class="row_heading level0 row1" >O60674</th>
#                         <td id="T_9059f_row1_col0" class="data row1 col0" >0.446959</td>
#                         <td id="T_9059f_row1_col1" class="data row1 col1" >0.101456</td>
#                         <td id="T_9059f_row1_col2" class="data row1 col2" >0.301975</td>
#                         <td id="T_9059f_row1_col3" class="data row1 col3" >0.139246</td>
#                         <td id="T_9059f_row1_col4" class="data row1 col4" >0.328279</td>
#                         <td id="T_9059f_row1_col5" class="data row1 col5" >0.251472</td>
#                         <td id="T_9059f_row1_col6" class="data row1 col6" >0.531679</td>
#                         <td id="T_9059f_row1_col7" class="data row1 col7" >0.138897</td>
#                         <td id="T_9059f_row1_col8" class="data row1 col8" >1.087380</td>
#                         <td id="T_9059f_row1_col9" class="data row1 col9" >0.477022</td>
#                         <td id="T_9059f_row1_col10" class="data row1 col10" >1.822168</td>
#                         <td id="T_9059f_row1_col11" class="data row1 col11" >1.324814</td>
#                         <td id="T_9059f_row1_col12" class="data row1 col12" >-2.298713</td>
#                         <td id="T_9059f_row1_col13" class="data row1 col13" >1.544693</td>
#                         <td id="T_9059f_row1_col14" class="data row1 col14" >1.238906</td>
#                         <td id="T_9059f_row1_col15" class="data row1 col15" >0.535986</td>
#             </tr>
#             <tr>
#                         <th id="T_9059f_level0_row2" class="row_heading level0 row2" >O60885</th>
#                         <td id="T_9059f_row2_col0" class="data row2 col0" >0.435203</td>
#                         <td id="T_9059f_row2_col1" class="data row2 col1" >0.071846</td>
#                         <td id="T_9059f_row2_col2" class="data row2 col2" >0.279574</td>
#                         <td id="T_9059f_row2_col3" class="data row2 col3" >0.075745</td>
#                         <td id="T_9059f_row2_col4" class="data row2 col4" >0.724047</td>
#                         <td id="T_9059f_row2_col5" class="data row2 col5" >0.069094</td>
#                         <td id="T_9059f_row2_col6" class="data row2 col6" >0.523652</td>
#                         <td id="T_9059f_row2_col7" class="data row2 col7" >0.073230</td>
# <style  type="text/css" >
# #T_c83eb_row1_col0,#T_c83eb_row1_col1,#T_c83eb_row1_col2,#T_c83eb_row1_col3,#T_c83eb_row2_col0,#T_c83eb_row2_col1,#T_c83eb_row2_col2,#T_c83eb_row2_col3{
#             font-weight:  bold;
#         }</style><table id="T_c83eb_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >train_r2_mean</th>        <th class="col_heading level0 col1" >train_r2_std</th>        <th class="col_heading level0 col2" >test_r2_mean</th>        <th class="col_heading level0 col3" >test_r2_std</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c83eb_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_c83eb_row0_col0" class="data row0 col0" >8.000000</td>
#                         <td id="T_c83eb_row0_col1" class="data row0 col1" >8.000000</td>
#                         <td id="T_c83eb_row0_col2" class="data row0 col2" >8.000000</td>
#                         <td id="T_c83eb_row0_col3" class="data row0 col3" >8.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_c83eb_level0_row1" class="row_heading level0 row1" >mean</th>
#                         <td id="T_c83eb_row1_col0" class="data row1 col0" >3.440361</td>
#                         <td id="T_c83eb_row1_col1" class="data row1 col1" >3.135620</td>
#                         <td id="T_c83eb_row1_col2" class="data row1 col2" >-13.606561</td>
#                         <td id="T_c83eb_row1_col3" class="data row1 col3" >50.605678</td>
#             </tr>
#             <tr>
#                         <th id="T_c83eb_level0_row2" class="row_heading level0 row2" >std</th>
#                         <td id="T_c83eb_row2_col0" class="data row2 col0" >8.312912</td>
#                         <td id="T_c83eb_row2_col1" class="data row2 col1" >8.431346</td>
#                         <td id="T_c83eb_row2_col2" class="data row2 col2" >49.907399</td>
#                         <td id="T_c83eb_row2_col3" class="data row2 col3" >83.061527</td>
#             </tr>
#             <tr>
#                         <th id="T_c83eb_level0_row3" class="row_heading level0 row3" >min</th>
#                         <td id="T_c83eb_row3_col0" class="data row3 col0" >-0.044062</td>
#                         <td id="T_c83eb_row3_col1" class="data row3 col1" >0.012091</td>
#                         <td id="T_c83eb_row3_col2" class="data row3 col2" >-128.639628</td>
#                         <td id="T_c83eb_row3_col3" class="data row3 col3" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_c83eb_level0_row4" class="row_heading level0 row4" >25%</th>
#                         <td id="T_c83eb_row4_col0" class="data row4 col0" >0.344357</td>
#                         <td id="T_c83eb_row4_col1" class="data row4 col1" >0.102446</td>
#                         <td id="T_c83eb_row4_col2" class="data row4 col2" >-17.098206</td>
#                         <td id="T_c83eb_row4_col3" class="data row4 col3" >1.716792</td>
#             </tr>
#             <tr>
#                         <th id="T_c83eb_level0_row5" class="row_heading level0 row5" >50%</th>
#                         <td id="T_c83eb_row5_col0" class="data row5 col0" >0.621378</td>
#                         <td id="T_c83eb_row5_col1" class="data row5 col1" >0.129586</td>
#                         <td id="T_c83eb_row5_col2" class="data row5 col2" >-1.488227</td>
#                         <td id="T_c83eb_row5_col3" class="data row5 col3" >26.258118</td>
#             </tr>
#             <tr>
#                         <th id="T_c83eb_level0_row6" class="row_heading level0 row6" >75%</th>
#                         <td id="T_c83eb_row6_col0" class="data row6 col0" >0.798736</td>
#                         <td id="T_c83eb_row6_col1" class="data row6 col1" >0.261692</td>
#                         <td id="T_c83eb_row6_col2" class="data row6 col2" >6.000000</td>
#                         <td id="T_c83eb_row6_col3" class="data row6 col3" >42.246385</td>
#             </tr>
#             <tr>
#                         <th id="T_c83eb_level0_row7" class="row_heading level0 row7" >max</th>
#                         <td id="T_c83eb_row7_col0" class="data row7 col0" >24.000000</td>
#                         <td id="T_c83eb_row7_col1" class="data row7 col1" >24.000000</td>
#                         <td id="T_c83eb_row7_col2" class="data row7 col2" >34.075038</td>
#                         <td id="T_c83eb_row7_col3" class="data row7 col3" >248.583672</td>
#             </tr>
#     </tbody></table>

# %%
print("Run finished at", datetime.now())
# Out:
# Run finished at 2021-04-09 16:35:35.991999

# %% [markdown]
# ### Save reports to disk

# %%
from kinoml.utils import watermark
w = watermark()
# Out:
# Watermark
# ---------
# Last updated: 2021-04-09T16:35:36.040873+02:00
#
# Python implementation: CPython
# Python version       : 3.8.8
# IPython version      : 7.22.0
#
# Compiler    : GCC 9.3.0
# OS          : Linux
# Release     : 4.19.128-microsoft-standard
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 8
# Architecture: 64bit
#
# Hostname: jrodriguez
#
# Git hash: d5cd0b3e0d894abb37c63da95d9a510eb6b1997d
#
# sys              : 3.8.8 | packaged by conda-forge | (default, Feb 20 2021, 16:22:27)
# [GCC 9.3.0]
# pandas           : 1.2.3
# pytorch_lightning: 1.2.7
# json             : 2.0.9
# torch            : 1.7.1.post2
# kinoml           : 0+untagged.409.gc193ba7.dirty
# numpy            : 1.20.2
#
# Watermark: 2.2.0
#
#
# nvidia-smi
# ----------
# stdout:
# NVIDIA-SMI has failed because it couldn't communicate with the NVIDIA driver. Make sure that the latest NVIDIA driver is installed and running.
#
# conda info
# ----------
# sys.version: 3.7.6 | packaged by conda-forge | (defau...
# sys.prefix: /opt/miniconda
# sys.executable: /opt/miniconda/bin/python
# conda location: /opt/miniconda/lib/python3.7/site-packages/conda
# conda-build: /opt/miniconda/bin/conda-build
# conda-convert: /opt/miniconda/bin/conda-convert
# conda-debug: /opt/miniconda/bin/conda-debug
# conda-develop: /opt/miniconda/bin/conda-develop
# conda-env: /opt/miniconda/bin/conda-env
# conda-index: /opt/miniconda/bin/conda-index
# conda-inspect: /opt/miniconda/bin/conda-inspect
# conda-metapackage: /opt/miniconda/bin/conda-metapackage
# conda-render: /opt/miniconda/bin/conda-render
# conda-server: /opt/miniconda/bin/conda-server
# conda-skeleton: /opt/miniconda/bin/conda-skeleton
# conda-smithy: /opt/miniconda/bin/conda-smithy
# user site dirs: ~/.local/lib/python3.8
#                 ~/.local/lib/python3.7
#                 ~/.local/lib/python3.6
#
# CIO_TEST: <not set>
# CONDA_DEFAULT_ENV: experiments-binding-affinity
# CONDA_EXE: /opt/miniconda/bin/conda
# CONDA_PREFIX: /home/jaime/.conda/envs/experiments-binding-affinity
# CONDA_PREFIX_1: /opt/miniconda
# CONDA_PROMPT_MODIFIER: (experiments-binding-affinity)
# CONDA_PYTHON_EXE: /opt/miniconda/bin/python
# CONDA_ROOT: /opt/miniconda
# CONDA_SHLVL: 2
# CURL_CA_BUNDLE: <not set>
# PATH: /home/jaime/.conda/envs/experiments-binding-affinity/bin:/opt/miniconda/condabin:/home/jaime/.local/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/games:/usr/local/games:/usr/lib/wsl/lib:/mnt/c/Windows/system32:/mnt/c/Windows:/mnt/c/Windows/System32/Wbem:/mnt/c/Windows/System32/WindowsPowerShell/v1.0:/mnt/c/Windows/System32/OpenSSH:/mnt/c/Program Files (x86)/NVIDIA Corporation/PhysX/Common:/mnt/c/WINDOWS/system32:/mnt/c/WINDOWS:/mnt/c/WINDOWS/System32/Wbem:/mnt/c/WINDOWS/System32/WindowsPowerShell/v1.0:/mnt/c/WINDOWS/System32/OpenSSH:/mnt/c/Program Files (x86)/Windows Kits/10/Windows Performance Toolkit:/mnt/c/Program Files/Intel/WiFi/bin:/mnt/c/Program Files/Common Files/Intel/WirelessCommon:/mnt/c/Android:/mnt/c/Program Files (x86)/Intel/Intel(R) Management Engine Components/DAL:/mnt/c/Program Files/Intel/Intel(R) Management Engine Components/DAL:/mnt/c/Program Files/NVIDIA Corporation/Nsight Compute 2020.1.2:/mnt/c/WINDOWS/system32:/mnt/c/WINDOWS:/mnt/c/WINDOWS/System32/Wbem:/mnt/c/WINDOWS/System32/WindowsPowerShell/v1.0:/mnt/c/WINDOWS/System32/OpenSSH:/mnt/c/Program Files/Docker/Docker/resources/bin:/mnt/c/ProgramData/DockerDesktop/version-bin:/mnt/c/Users/Jaime/AppData/Local/Microsoft/WindowsApps:/mnt/c/Users/Jaime/AppData/Local/Programs/Microsoft VS Code/bin:/mnt/c/Program Files (x86)/mingw-w64/i686-8.1.0-posix-dwarf-rt_v6-rev0/mingw32/bin:/mnt/c/G09W:/mnt/c/Program Files (x86)/FAHClient:/mnt/c/Program Files/7-Zip:/mnt/c/Users/Jaime/AppData/Local/atom/bin:/mnt/c/Users/Jaime/AppData/Local/Microsoft/WindowsApps:/snap/bin
# PYTHONHASHSEED: 1234
# REQUESTS_CA_BUNDLE: <not set>
# SSL_CERT_FILE: <not set>
#
# conda list
# ----------
# # packages in environment at /home/jaime/.conda/envs/experiments-binding-affinity:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                 conda_forge    conda-forge
# _openmp_mutex             4.5                      1_llvm    conda-forge
# _py-xgboost-mutex         2.0                       cpu_0    conda-forge
# absl-py                   0.12.0             pyhd8ed1ab_0    conda-forge
# aiohttp                   3.7.4            py38h497a2fe_0    conda-forge
# alabaster                 0.7.12                   pypi_0    pypi
# amberlite                 16.0                     pypi_0    pypi
# ambertools                20.15                    pypi_0    pypi
# ansiwrap                  0.8.4                      py_0    conda-forge
# anyio                     2.2.0            py38h578d9bd_0    conda-forge
# appdirs                   1.4.4              pyh9f0ad1d_0    conda-forge
# argon2-cffi               20.1.0           py38h497a2fe_2    conda-forge
# arpack                    3.7.0                hdefa2d7_2    conda-forge
# ase                       3.21.1                   pypi_0    pypi
# astunparse                1.6.2                      py_0    conda-forge
# async-timeout             3.0.1                   py_1000    conda-forge
# async_generator           1.10                       py_0    conda-forge
# attrs                     20.3.0             pyhd3deb0d_0    conda-forge
# babel                     2.9.0              pyhd3deb0d_0    conda-forge
# backcall                  0.2.0              pyh9f0ad1d_0    conda-forge
# backports                 1.0                        py_2    conda-forge
# backports.functools_lru_cache 1.6.3              pyhd8ed1ab_0    conda-forge
# black                     20.8b1                     py_1    conda-forge
# bleach                    3.3.0              pyh44b312d_0    conda-forge
# blinker                   1.4                        py_1    conda-forge
# blosc                     1.21.0               h9c3ff4c_0    conda-forge
# boost                     1.74.0           py38hc10631b_3    conda-forge
# boost-cpp                 1.74.0               hc6e9bd1_2    conda-forge
# brotlipy                  0.7.0           py38h497a2fe_1001    conda-forge
# bzip2                     1.0.8                h7f98852_4    conda-forge
# c-ares                    1.17.1               h7f98852_1    conda-forge
# ca-certificates           2021.1.19            h06a4308_1
# cachetools                4.2.1              pyhd8ed1ab_0    conda-forge
# cairo                     1.16.0            h6cf1ce9_1008    conda-forge
# certifi                   2020.12.5        py38h578d9bd_1    conda-forge
# cffi                      1.14.5           py38ha65f79e_0    conda-forge
# chardet                   4.0.0            py38h578d9bd_1    conda-forge
# click                     7.1.2              pyh9f0ad1d_0    conda-forge
# cryptography              3.4.7            py38ha5dfef3_0    conda-forge
# cudatoolkit               10.1.243             h036e899_8    conda-forge
# curl                      7.76.0               h979ede3_0    conda-forge
# cycler                    0.10.0                     py_2    conda-forge
# cython                    0.29.22          py38h709712a_0    conda-forge
# dataclasses               0.8                pyhc8e2a94_1    conda-forge
# decorator                 4.4.2                      py_0    conda-forge
# defusedxml                0.7.1              pyhd8ed1ab_0    conda-forge
# docutils                  0.17                     pypi_0    pypi
# entrypoints               0.3             py38h32f6830_1002    conda-forge
# fftw                      3.3.9           nompi_hcdd671c_101    conda-forge
# fontconfig                2.13.1            hba837de_1004    conda-forge
# freetype                  2.10.4               h0708190_1    conda-forge
# fsspec                    0.9.0              pyhd8ed1ab_0    conda-forge
# future                    0.18.2           py38h578d9bd_3    conda-forge
# gettext                   0.21.0               hf68c758_0
# google-auth               1.28.0             pyh44b312d_0    conda-forge
# google-auth-oauthlib      0.4.1                      py_2    conda-forge
# googledrivedownloader     0.4                      pypi_0    pypi
# greenlet                  1.0.0            py38h709712a_0    conda-forge
# grpcio                    1.37.0           py38hdd6454d_0    conda-forge
# h5py                      3.2.1                    pypi_0    pypi
# hdf4                      4.2.13            h10796ff_1004    conda-forge
# hdf5                      1.10.6          nompi_h6a2412b_1114    conda-forge
# icu                       68.1                 h58526e2_0    conda-forge
# idna                      2.10               pyh9f0ad1d_0    conda-forge
# imagesize                 1.2.0                    pypi_0    pypi
# importlib-metadata        3.10.0           py38h578d9bd_0    conda-forge
# importlib_metadata        3.10.0               hd8ed1ab_0    conda-forge
# importlib_resources       5.1.2            py38h578d9bd_0    conda-forge
# ipykernel                 5.5.3            py38hd0cf306_0    conda-forge
# ipython                   7.22.0           py38hd0cf306_0    conda-forge
# ipython_genutils          0.2.0                      py_1    conda-forge
# ipywidgets                7.6.3              pyhd3deb0d_0    conda-forge
# isodate                   0.6.0                    pypi_0    pypi
# jedi                      0.18.0           py38h578d9bd_2    conda-forge
# jinja2                    2.11.3             pyh44b312d_0    conda-forge
# joblib                    1.0.1              pyhd8ed1ab_0    conda-forge
# jpeg                      9d                   h516909a_0    conda-forge
# json5                     0.9.5              pyh9f0ad1d_0    conda-forge
# jsonschema                3.2.0            py38h32f6830_1    conda-forge
# jupyter-packaging         0.7.12             pyhd8ed1ab_0    conda-forge
# jupyter_client            6.1.12             pyhd8ed1ab_0    conda-forge
# jupyter_core              4.7.1            py38h578d9bd_0    conda-forge
# jupyter_server            1.5.1            py38h578d9bd_0    conda-forge
# jupyterlab                3.0.12             pyhd8ed1ab_0    conda-forge
# jupyterlab_pygments       0.1.2              pyh9f0ad1d_0    conda-forge
# jupyterlab_server         2.4.0              pyhd8ed1ab_0    conda-forge
# jupyterlab_widgets        1.0.0              pyhd8ed1ab_1    conda-forge
# kinoml                    0+untagged.409.gc193ba7.dirty          pypi_0    pypi
# kiwisolver                1.3.1            py38h1fd1430_1    conda-forge
# krb5                      1.17.2               h926e7f8_0    conda-forge
# lcms2                     2.12                 hddcbb42_0    conda-forge
# ld_impl_linux-64          2.35.1               hea4e1c9_2    conda-forge
# libblas                   3.9.0                     8_mkl    conda-forge
# libcblas                  3.9.0                     8_mkl    conda-forge
# libcurl                   7.76.0               hc4aaa36_0    conda-forge
# libedit                   3.1.20210216         h27cfd23_1
# libev                     4.33                 h516909a_1    conda-forge
# libffi                    3.3                  h58526e2_2    conda-forge
# libgcc-ng                 9.3.0               h2828fa1_18    conda-forge
# libgfortran-ng            9.3.0               hff62375_18    conda-forge
# libgfortran5              9.3.0               hff62375_18    conda-forge
# libglib                   2.68.0               h3e27bee_2    conda-forge
# libgomp                   9.3.0               h2828fa1_18    conda-forge
# libiconv                  1.16                 h516909a_0    conda-forge
# liblapack                 3.9.0                     8_mkl    conda-forge
# libnetcdf                 4.7.4           nompi_h56d31a8_107    conda-forge
# libnghttp2                1.43.0               h812cca2_0    conda-forge
# libpng                    1.6.37               hed695b0_2    conda-forge
# libprotobuf               3.15.7               h780b84a_0    conda-forge
# libsodium                 1.0.18               h516909a_1    conda-forge
# libssh2                   1.9.0                ha56f1ee_6    conda-forge
# libstdcxx-ng              9.3.0               h6de172a_18    conda-forge
# libtiff                   4.2.0                hdc55705_0    conda-forge
# libuuid                   2.32.1            h14c3975_1000    conda-forge
# libwebp-base              1.2.0                h7f98852_2    conda-forge
# libxcb                    1.14                 h7b6447c_0
# libxgboost                1.3.3                h9c3ff4c_2    conda-forge
# libxml2                   2.9.10               h72842e0_3    conda-forge
# llvm-openmp               11.1.0               h4bd325d_1    conda-forge
# llvmlite                  0.36.0                   pypi_0    pypi
# lz4-c                     1.9.3                h9c3ff4c_0    conda-forge
# lzo                       2.10              h516909a_1000    conda-forge
# markdown                  3.3.4              pyhd8ed1ab_0    conda-forge
# markupsafe                1.1.1            py38h497a2fe_3    conda-forge
# matplotlib-base           3.4.1            py38hcc49a3a_0    conda-forge
# mdtraj                    1.9.5            py38hbcc7ddf_1    conda-forge
# mistune                   0.8.4           py38h497a2fe_1003    conda-forge
# mkl                       2020.4             h726a3e6_304    conda-forge
# mmpbsa-py                 16.0                     pypi_0    pypi
# mock                      4.0.3            py38h578d9bd_1    conda-forge
# multidict                 5.1.0            py38h497a2fe_1    conda-forge
# mypy_extensions           0.4.3            py38h578d9bd_3    conda-forge
# nbclassic                 0.2.7              pyhd8ed1ab_0    conda-forge
# nbclient                  0.5.3              pyhd8ed1ab_0    conda-forge
# nbconvert                 6.0.7            py38h578d9bd_3    conda-forge
# nbformat                  5.1.3              pyhd8ed1ab_0    conda-forge
# ncurses                   6.2                  h58526e2_4    conda-forge
# nest-asyncio              1.5.1              pyhd8ed1ab_0    conda-forge
# netcdf-fortran            4.5.3           nompi_h996563d_103    conda-forge
# networkx                  2.5.1              pyhd8ed1ab_0    conda-forge
# nglview                   2.7.8              pyh59e0f4d_0    conda-forge
# nglview-js-widgets        2.7.7                    pypi_0    pypi
# ninja                     1.10.2               h4bd325d_0    conda-forge
# notebook                  6.3.0            py38h578d9bd_0    conda-forge
# numba                     0.53.1                   pypi_0    pypi
# numexpr                   2.7.3            py38h51da96c_0    conda-forge
# numpy                     1.20.2           py38h9894fe3_0    conda-forge
# oauthlib                  3.1.0                      py_0
# ocl-icd                   2.3.0                h7f98852_0    conda-forge
# ocl-icd-system            1.0.0                         1    conda-forge
# olefile                   0.46               pyh9f0ad1d_1    conda-forge
# openff-forcefields        1.3.0              pyh44b312d_0    conda-forge
# openff-toolkit            0.9.1              pyhd8ed1ab_2    conda-forge
# openff-toolkit-base       0.9.1              pyhd8ed1ab_2    conda-forge
# openmm                    7.5.0            py38hc16d3cc_6    conda-forge
# openssl                   1.1.1k               h7f98852_0    conda-forge
# packaging                 20.9               pyh44b312d_0    conda-forge
# packmol-memgen            1.1.0rc0                 pypi_0    pypi
# pandas                    1.2.3            py38h51da96c_0    conda-forge
# pandoc                    2.12                 h7f98852_0    conda-forge
# pandocfilters             1.4.3            py38h06a4308_1
# papermill                 2.2.2              pyhd8ed1ab_0    conda-forge
# parmed                    3.4.0            py38h709712a_1    conda-forge
# parso                     0.8.2              pyhd8ed1ab_0    conda-forge
# pathspec                  0.8.1              pyhd3deb0d_0    conda-forge
# pcre                      8.44                 he1b5a44_0    conda-forge
# pdb4amber                 1.7.dev0                 pypi_0    pypi
# perl                      5.32.0               h36c2ea0_0    conda-forge
# pexpect                   4.8.0            py38h32f6830_1    conda-forge
# pickleshare               0.7.5           py38h32f6830_1002    conda-forge
# pillow                    8.2.0            py38he98fc37_0
# pint                      0.17               pyhd8ed1ab_0    conda-forge
# pip                       21.0.1             pyhd8ed1ab_0    conda-forge
# pixman                    0.40.0               h36c2ea0_0    conda-forge
# prometheus_client         0.10.0             pyhd8ed1ab_0    conda-forge
# prompt-toolkit            3.0.18             pyha770c72_0    conda-forge
# protobuf                  3.15.7           py38h709712a_0    conda-forge
# ptyprocess                0.7.0              pyhd3deb0d_0    conda-forge
# py-xgboost                1.3.3            py38h578d9bd_2    conda-forge
# pyasn1                    0.4.8                      py_0    conda-forge
# pyasn1-modules            0.2.8                      py_0
# pycairo                   1.20.0           py38h323dad1_1    conda-forge
# pycparser                 2.20               pyh9f0ad1d_2    conda-forge
# pygments                  2.8.1              pyhd8ed1ab_0    conda-forge
# pyjwt                     2.0.1              pyhd8ed1ab_1    conda-forge
# pyopenssl                 20.0.1             pyhd8ed1ab_0    conda-forge
# pyparsing                 2.4.7              pyh9f0ad1d_0    conda-forge
# pyrsistent                0.17.3           py38h497a2fe_2    conda-forge
# pysocks                   1.7.1            py38h578d9bd_3    conda-forge
# pytables                  3.6.1            py38hf9f05d5_3    conda-forge
# python                    3.8.8           hffdb5ce_0_cpython    conda-forge
# python-dateutil           2.8.1                      py_0    conda-forge
# python-louvain            0.15                     pypi_0    pypi
# python_abi                3.8                      1_cp38    conda-forge
# pytorch                   1.7.1           cpu_py38h36eccb8_2    conda-forge
# pytorch-lightning         1.2.7              pyhd8ed1ab_0    conda-forge
# pytraj                    2.0.5                    pypi_0    pypi
# pytz                      2021.1             pyhd8ed1ab_0    conda-forge
# pyyaml                    5.4.1            py38h497a2fe_0    conda-forge
# pyzmq                     22.0.3           py38h2035c66_1    conda-forge
# rdflib                    5.0.0                    pypi_0    pypi
# rdkit                     2021.03.1        py38hf8acc3d_0    conda-forge
# readline                  8.1                  h27cfd23_0
# regex                     2021.4.4         py38h497a2fe_0    conda-forge
# reportlab                 3.5.66           py38hadf75a6_0    conda-forge
# requests                  2.25.1             pyhd3deb0d_0    conda-forge
# requests-oauthlib         1.3.0              pyh9f0ad1d_0    conda-forge
# rsa                       4.7.2              pyh44b312d_0    conda-forge
# ruamel.yaml               0.16.12          py38h497a2fe_2    conda-forge
# ruamel.yaml.clib          0.2.2            py38h497a2fe_2    conda-forge
# sander                    16.0                     pypi_0    pypi
# scikit-learn              0.24.1           py38h658cfdd_0    conda-forge
# scipy                     1.6.2            py38h7b17777_0    conda-forge
# send2trash                1.5.0                      py_0    conda-forge
# setuptools                52.0.0           py38h06a4308_0
# six                       1.15.0             pyh9f0ad1d_0    conda-forge
# sklearn-pytorch           0.1.0                    pypi_0    pypi
# smirnoff99frosst          1.1.0              pyh44b312d_0    conda-forge
# snappy                    1.1.8                he1b5a44_3    conda-forge
# sniffio                   1.2.0            py38h578d9bd_1    conda-forge
# snowballstemmer           2.1.0                    pypi_0    pypi
# sphinx                    3.5.3                    pypi_0    pypi
# sphinxcontrib-applehelp   1.0.2                    pypi_0    pypi
# sphinxcontrib-devhelp     1.0.2                    pypi_0    pypi
# sphinxcontrib-htmlhelp    1.0.3                    pypi_0    pypi
# sphinxcontrib-jsmath      1.0.1                    pypi_0    pypi
# sphinxcontrib-qthelp      1.0.3                    pypi_0    pypi
# sphinxcontrib-serializinghtml 1.1.4                    pypi_0    pypi
# sqlalchemy                1.4.6            py38h497a2fe_0    conda-forge
# sqlite                    3.35.4               h74cdb3f_0    conda-forge
# tenacity                  7.0.0              pyhd8ed1ab_0    conda-forge
# tensorboard               2.4.1              pyhd8ed1ab_0    conda-forge
# tensorboard-plugin-wit    1.8.0              pyh44b312d_0    conda-forge
# terminado                 0.9.4            py38h578d9bd_0    conda-forge
# testpath                  0.4.4                      py_0    conda-forge
# textwrap3                 0.9.2                      py_0    conda-forge
# threadpoolctl             2.1.0              pyh5ca1d4c_0    conda-forge
# tk                        8.6.10               hed695b0_1    conda-forge
# toml                      0.10.2             pyhd8ed1ab_0    conda-forge
# torch-cluster             1.5.9                    pypi_0    pypi
# torch-geometric           1.6.3                    pypi_0    pypi
# torch-scatter             2.0.6                    pypi_0    pypi
# torch-sparse              0.6.9                    pypi_0    pypi
# torch-spline-conv         1.2.1                    pypi_0    pypi
# torchmetrics              0.2.0              pyhd8ed1ab_0    conda-forge
# torchvision               0.8.2           py38h89b28b9_1_cpu    conda-forge
# tornado                   6.1              py38h497a2fe_1    conda-forge
# tqdm                      4.60.0             pyhd8ed1ab_0    conda-forge
# traitlets                 5.0.5                      py_0    conda-forge
# typed-ast                 1.4.2            py38h497a2fe_0    conda-forge
# typing-extensions         3.7.4.3                       0    conda-forge
# typing_extensions         3.7.4.3                    py_0    conda-forge
# urllib3                   1.26.4             pyhd8ed1ab_0    conda-forge
# watermark                 2.2.0              pyhd8ed1ab_0    conda-forge
# wcwidth                   0.2.5              pyh9f0ad1d_2    conda-forge
# webencodings              0.5.1                      py_1    conda-forge
# werkzeug                  1.0.1              pyh9f0ad1d_0    conda-forge
# wheel                     0.36.2             pyhd3deb0d_0    conda-forge
# widgetsnbextension        3.5.1            py38h578d9bd_4    conda-forge
# xgboost                   1.3.3            py38h578d9bd_2    conda-forge
# xmltodict                 0.12.0                     py_0    conda-forge
# xorg-kbproto              1.0.7             h14c3975_1002    conda-forge
# xorg-libice               1.0.10               h516909a_0    conda-forge
# xorg-libsm                1.2.3             hd9c2040_1000    conda-forge
# xorg-libx11               1.7.0                h36c2ea0_0    conda-forge
# xorg-libxext              1.3.4                h7f98852_1    conda-forge
# xorg-libxrender           0.9.10            h7f98852_1003    conda-forge
# xorg-libxt                1.2.1                h7f98852_2    conda-forge
# xorg-renderproto          0.11.1            h14c3975_1002    conda-forge
# xorg-xextproto            7.3.0             h14c3975_1002    conda-forge
# xorg-xproto               7.0.31            h14c3975_1007    conda-forge
# xz                        5.2.5                h516909a_1    conda-forge
# yaml                      0.2.5                h516909a_0    conda-forge
# yarl                      1.6.3            py38h497a2fe_1    conda-forge
# zeromq                    4.3.4                h9c3ff4c_0    conda-forge
# zipp                      3.4.1              pyhd8ed1ab_0    conda-forge
# zlib                      1.2.11            h516909a_1010    conda-forge
# zstd                      1.4.9                ha95c52a_0    conda-forge

# %%
# %%capture cap --no-stderr
w = watermark()

# %%
import json

df.to_csv(OUT / "performance.csv")

with open(OUT / "performance.json", "w") as f:
    json.dump(kinase_metrics, f, default=str, indent=2)
    
with open(OUT/ "watermark.txt", "w") as f:
    f.write(cap.stdout)

with open(OUT / "hparams.json", "w") as f:
    json.dump(_hparams, f, default=str, indent=2)
